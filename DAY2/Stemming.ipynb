# %%
#  pip install stemming==1.0
# pip install ntlk

# %%
# !gdown --id 1ukwa4aQM_0dGAPzIpSzApE2Gj5qT0ZKn
# !ls -al

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import nltk
from nltk.corpus import state_union
nltk.download('state_union')
sample_text = state_union.raw("2006-GWBush.txt")
# Out:
# [nltk_data] Downloading package state_union to /root/nltk_data...
# [nltk_data]   Unzipping corpora/state_union.zip.

# %%
sample_text
# Out:
# 'PRESIDENT GEORGE W. BUSH\'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS ON THE STATE OF THE UNION\n \nJanuary 31, 2006\n\nTHE PRESIDENT: Thank you all. Mr. Speaker, Vice President Cheney, members of Congress, members of the Supreme Court and diplomatic corps, distinguished guests, and fellow citizens: Today our nation lost a beloved, graceful, courageous woman who called America to its founding ideals and carried on a noble dream. Tonight we are comforted by the hope of a glad reunion with the husband who was taken so long ago, and we are grateful for the good life of Coretta Scott King. (Applause.)\n\nPresident George W. Bush reacts to applause during his State of the Union Address at the Capitol, Tuesday, Jan. 31, 2006. White House photo by Eric DraperEvery time I\'m invited to this rostrum, I\'m humbled by the privilege, and mindful of the history we\'ve seen together. We have gathered under this Capitol dome in moments of national mourning and national achievement. We have se
# ...

# %%
from keras.preprocessing.text import text_to_word_sequence
import re
import nltk
from nltk.corpus import stopwords
tokenized_text = text_to_word_sequence(sample_text)

# %%
tokenized_text
# Out:
# ['president',
#  'george',
#  'w',
#  "bush's",
#  'address',
#  'before',
#  'a',
#  'joint',
#  'session',
#  'of',
#  'the',
#  'congress',
#  'on',
#  'the',
#  'state',
#  'of',
#  'the',
#  'union',
#  'january',
#  '31',
#  '2006',
#  'the',
#  'president',
#  'thank',
#  'you',
#  'all',
#  'mr',
#  'speaker',
#  'vice',
#  'president',
#  'cheney',
#  'members',
#  'of',
#  'congress',
#  'members',
#  'of',
#  'the',
#  'supreme',
#  'court',
#  'and',
#  'diplomatic',
#  'corps',
#  'distinguished',
#  'guests',
#  'and',
#  'fellow',
#  'citizens',
#  'today',
#  'our',
#  'nation',
#  'lost',
#  'a',
#  'beloved',
#  'graceful',
#  'courageous',
#  'woman',
#  'who',
#  'called',
#  'america',
#  'to',
#  'its',
#  'founding',
#  'ideals',
#  'and',
#  'carried',
#  'on',
#  'a',
#  'noble',
#  'dream',
#  'tonight',
#  'we',
#  'are',
#  'comforted',
#  'by',
#  'the',
#  'hope',
#  'of',
#  'a',
#  'glad',
#  'reunion',
#  'with',
#  'the',
#  'husband',
#  'who',
# ...

# %%
df=pd.DataFrame(columns=['text1'],data=tokenized_text)
df.head()
# Out:
#        text1
# 0  president
# 1     george
# 2          w
# 3     bush's
# 4    address

# %%
import string
a_string = '!hi. wh?at is the weat[h]er lik?e.'
new_string = a_string.translate(str.maketrans('', '', string.punctuation))
print(new_string)

# %%
nltk.download('stopwords')
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
# ...

# %%
import string
text2=[]
for text in tokenized_text:
  text=text.translate(str.maketrans('', '', string.punctuation))
  if text in stopwords.words('english') or len(text)<3 or len(text)>20 or re.match('[0-9]+',text):
    text2.append("")
  else:
    text2.append(text)
df['text2']=text2

# %%
aoooorightaaa

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
df[df['text2']=='']
# Out:
#        text1 text2
# 2          w
# 5     before
# 6          a
# 9         of
# 10       the
# ...      ...   ...
# 5563     its
# 5565     and
# 5567      of
# 5568     the
# 5570      to
#
# [2574 rows x 2 columns]

# %%
df
# Out:
#           text1      text2
# 0     president  president
# 1        george     george
# 2             w
# 3        bush's      bushs
# 4       address    address
# ...         ...        ...
# 5572        may        may
# 5573        god        god
# 5574      bless      bless
# 5575    america    america
# 5576   applause   applause
#
# [5577 rows x 2 columns]

# %%
" ".join(df['text2'].values)
# Out:
# 'president george  bushs address   joint session   congress   state   union january    president thank    speaker vice president cheney members  congress members   supreme court  diplomatic corps distinguished guests  fellow citizens today  nation lost  beloved graceful courageous woman  called america   founding ideals  carried   noble dream tonight   comforted   hope   glad reunion   husband   taken  long ago    grateful   good life  coretta scott king applause president george  bush reacts  applause   state   union address   capitol tuesday jan   white house photo  eric draperevery time  invited   rostrum  humbled   privilege  mindful   history weve seen together   gathered   capitol dome  moments  national mourning  national achievement   served america  one    consequential periods   history      honor  serve     system  two parties two chambers  two elected branches   always  differences  debate  even tough debates   conducted   civil tone   differences cannot  allowed  harden 
# ...

# %%
from nltk.stem import SnowballStemmer
snowball = SnowballStemmer(language='english')
snow=[]
for w in df['text2'].values:
  if w=='':
    snow.append(w)
  else:
    
    s= snowball.stem(w)
    snow.append(s)
df['snow']=snow

# %%
df
# Out:
#           text1      text2     snow
# 0     president  president   presid
# 1        george     george    georg
# 2             w
# 3        bush's      bushs     bush
# 4       address    address  address
# ...         ...        ...      ...
# 5572        may        may      may
# 5573        god        god      god
# 5574      bless      bless    bless
# 5575    america    america  america
# 5576   applause   applause  applaus
#
# [5577 rows x 3 columns]

# %%
df.loc[~(df['text2'] == df['snow'])]

# %%
from nltk.stem import LancasterStemmer
lancaster = LancasterStemmer()
lancast=[]
for w in df['text2'].values:
  if w=='':
    lancast.append(w)
  else:
    
    s= lancaster.stem(w)
    lancast.append(s)
df['lancast']=lancast

# %%
df.loc[~(df['text2'] == df['lancast'])]
# Out:
#           text1      text2     snow  lancast
# 0     president  president   presid   presid
# 1        george     george    georg    georg
# 3        bush's      bushs     bush     bush
# 8       session    session  session     sess
# 14        state      state    state     stat
# ...         ...        ...      ...      ...
# 5566  confident  confident   confid   confid
# 5569  victories  victories  victori     vict
# 5571       come       come     come      com
# 5575    america    america  america   americ
# 5576   applause   applause  applaus  applaus
#
# [2048 rows x 4 columns]

# %%
fact faction  factionally  
fact

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
porter=[]
for w in df['text2'].values:
  if w=='':
    porter.append(w)
  else:
    s= ps.stem(w)
    porter.append(s)
df['porter']=porter

# %%
df.loc[~(df['text2'] == df['porter'])]

# %%
#Unique words in first case
import operator
def distinct_words(list1):
  distinct_dict={}
  for word in list1:
    if word not in distinct_dict.keys():

      distinct_dict[word]=1
    else:
      distinct_dict[word]+=1
  return dict( sorted(distinct_dict.items(), key=operator.itemgetter(1),reverse=True))
text2=list(filter(None,list(df['text2'].values)))
text2_distinct_dict=distinct_words(text2)
print("length for text2 ",len(text2_distinct_dict.keys()))

# %%
#Unique words in first case
import operator
def distinct_words(list1):
  distinct_dict={}
  for word in list1:
    if word not in distinct_dict.keys():

      distinct_dict[word]=1
    else:
      distinct_dict[word]+=1
  return dict( sorted(distinct_dict.items(), key=operator.itemgetter(1),reverse=True))
snow=list(filter(None,list(df['snow'].values)))
snow_distinct_dict=distinct_words(snow)
print("length for snow ",len(snow_distinct_dict.keys()))
snow_distinct_dict

# %%
#Unique words in first case
import operator
def distinct_words(list1):
  distinct_dict={}
  for word in list1:
    if word not in distinct_dict.keys():

      distinct_dict[word]=1
    else:
      distinct_dict[word]+=1
  return dict( sorted(distinct_dict.items(), key=operator.itemgetter(1),reverse=True))
lancast=list(filter(None,list(df['lancast'].values)))
lancast_distinct_dict=distinct_words(lancast)
print("length for snow ",len(lancast_distinct_dict.keys()))

# %%
lancast_distinct_dict

# %%
#Unique words in first case
porter=list(filter(None,list(df['porter'].values)))
porter_distinct_dict=distinct_words(snow)
print("length for porter ",len(snow_distinct_dict.keys()))
porter_distinct_dict

# %%
# Performance 
#Index Compression Factor (ICF)
#The index compression factor represents a percent by which a collection of distinct words is reduced by stemming.
print("ICF for Snow ",(len(text2_distinct_dict.keys())-len(snow_distinct_dict.keys()))*100/len(snow_distinct_dict.keys()))
print("ICF for Porter ",(len(text2_distinct_dict.keys())-len(porter_distinct_dict.keys()))*100/len(porter_distinct_dict.keys()))
print("ICF for Lancaster ",(len(text2_distinct_dict.keys())-len(lancast_distinct_dict.keys()))*100/len(lancast_distinct_dict.keys()))

# %% [markdown]
# Other Stemmers

# %%
from nltk.stem import RegexpStemmer
regexp = RegexpStemmer('ing$|s$|e$|able$|an$', min=4)
words = ['connecting','connect','factionally','faction',"consult","consulation","American"]
for word in words:
    print(word,"--->",regexp.stem(word))

# %%
from stemming.paicehusk import stem as paicehusk_stemmer
from stemming.lovins import stem as  lovins_stemmer
# from stemming.porter import stem as  porter_stemmer
from stemming.porter2 import stem as  porter_stemmer1
from nltk.stem.snowball import SnowballStemmer
words=["mouse","mice","getting","sung","sing","cats","cat","indices","index"
,'agreed',"likes","liked"]
#stem's of each word
stem_words = []
for w in words:
  ph = paicehusk_stemmer(w)
  l = lovins_stemmer(w)
  p = porter_stemmer1(w)
  s= SnowballStemmer(language='english').stem(w)
  print(w," Paicehusk ->>",ph)
  print(w," lovins ->>",l)
  print(w," Porter2 ->>",p)
  print(w," Snowfall ->>",s)
  print("\n")

# %%
# we can use regular expression to stem words that are not stemmed by Stemmers
text="america americans american"
re.sub('america[a-z]{1,2}',"america",text,re.IGNORECASE)

# %% [markdown]
# # When not to use Stemming

# %% [markdown]
# # train data
# He played below-average football in 2013, but was viewed as an ascending player before that and can play guard or center.
#
# # test data
# We’re looking at a number of players, including Mark
#
#
# # Why it causes issues
# First sentence contains number of words referring to sports, including word "player". Second sentence from test set also mentions player, but, oh, it's in plural - "players", not "player" - so for classifier it is a distinct, unrelated variable.
#
#
# Stemming tries to cut off details like exact form of a word and produce word bases as features for classification. In example above, stemming could shorten both words to "player" (or even "play") and use them as the same feature

# %%
#
